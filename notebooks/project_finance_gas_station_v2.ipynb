# %% [markdown]
# # Gas Station Project Finance Model v2
#
# Full model with debt, taxes, working capital, maintenance capex, salvage value, DSCR, and scenarios.

# %%
from src.model_full import Assumptions, build_full_model, scenario_table, debt_capacity_sensitivity

a = Assumptions()
model, debt, metrics = build_full_model(a)
scenarios = scenario_table(a)
sens = debt_capacity_sensitivity(a)
metrics

# %%
model.head()

# %%
debt.head()

# %%
scenarios

# %%
sens.head()
